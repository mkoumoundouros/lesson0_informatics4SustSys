# %% [markdown]
# # **My first program in Python**
# ##### This is a quick review of the core concept we discussed in class during the "crash course to coding" session.
# #### This is a quick review of the core concept we discussed in class during the "crash course to coding" session.
# ### This is a quick review of the core concept we discussed in class during the "crash course to coding" session.
#
# ```python
# print "Hello World"
# ```
#
# https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html

# %%
# This is a comment line. It will no be interpreted as a Python instruction
name = input()
print('Hello ', name)
# Out:
#  he
# Hello  he

# %% [markdown]
# # My first program in Python
# ## What we learned in class
# ![image.png](attachment:d0780778-ffa2-434a-b328-19f17d8370e9.png)

# %%
# Goal: compute the average of a list

avg = total / len(numbers)
numbers = [10, 20, 30, 40]
total = sum(numbers)

print("Average:", avg)

# %% [markdown]
# ## Try writing the code described in the flowchart and pseudocode below
# ![image.png](attachment:f0a8d594-dde8-4730-9763-989aaffb628a.png)
